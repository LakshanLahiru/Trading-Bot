# %%
pip install yfinance --upgrade --no-cache-dir

# %%
#Import yfinance and datetime
import yfinance as yf
import datetime
import numpy as np

# %%
# collect the data from 2006-01-01 to Now

start = datetime.datetime(2006,1,1
end = datetime.datetime(2024,2,1)
#end = datetime.datetime.today()

df = yf.download("SPY",start=start,end=end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  472.160004  473.670013  470.489990  472.649994  472.649994
# 2024-01-03  470.429993  471.190002  468.170013  468.790009  468.790009
# 2024-01-04  468.299988  470.959991  467.049988  467.279999  467.279999
# 2024-01-05  467.489990  470.440002  466.429993  467.920013  467.920013
# 2024-01-08  468.429993  474.750000  468.299988  474.600006  474.600006
# 2024-01-09  471.869995  474.929993  471.350006  473.880005  473.880005
# 2024-01-10  474.160004  477.450012  473.869995  476.559998  476.559998
# 2024-01-11  477.589996  478.119995  472.260010  476.350006  476.350006
# 2024-01-12  477.839996  478.600006  475.230011  476.679993  476.679993
# 2024-01-16  475.260010  476.609985  473.059998  474.929993  474.929993
# 2024-01-17  471.820007  472.790009  469.869995  472.290009  472.290009
# 2024-01-18  474.010010  477.059998  472.420013  476.489990  476.489990
# 2024-01-19  477.649994  482.720001  476.540009  482.429993  482.429993
# 2024-01-22  484.010010  485.220001  482.779999  483.450012  483.450012
# 2024-01-23  484.010010  485.109985  482.890015  484.859985  484.859985
# 2024-01-24  487.809998  488.769989  484.880005  485.390015  485.390015
# 2024-01-25  487.579987  488.309998  485.390015  488.029999  488.029999
# 2024-01-26  487.589996  489.119995  486.540009  487.410004  487.410004
# 2024-01-29  487.730011  491.420013  487.170013  491.269989  491.269989
# 2024-01-30  490.559998  491.619995  490.109985  490.890015  490.890015
# 2024-01-31  488.619995  489.079987  482.859985  482.880005  482.880005
#
#                Volume
# Date
# 2024-01-02  123623700
# 2024-01-03  103585900
# 2024-01-04   84232200
# 2024-01-05   86060800
# 2024-01-08   74879100
# 2024-01-09   65931400
# 2024-01-10   67310600
# 2024-01-11   77940700
# 2024-01-12   57944000
# 2024-01-16   85014900
# 2024-01-17   68843900
# 2024-01-18   91856200
# 2024-01-19  110733300
# 2024-01-22   75844900
# 2024-01-23   49945300
# 2024-01-24   81765000
# 2024-01-25   72525000
# 2024-01-26   76641600
# 2024-01-29   61322800
# 2024-01-30   58618400
# 2024-01-31  126011100

# %%
# (Rename the column 'Adj Close'  to  'prc' )

# %%
df.rename(columns={'Adj Close':'prc'},inplace=True )

# %%
df.head()
# Out:
#                   Open        High         Low       Close         prc  \
# Date
# 2024-01-02  472.160004  473.670013  470.489990  472.649994  472.649994
# 2024-01-03  470.429993  471.190002  468.170013  468.790009  468.790009
# 2024-01-04  468.299988  470.959991  467.049988  467.279999  467.279999
# 2024-01-05  467.489990  470.440002  466.429993  467.920013  467.920013
# 2024-01-08  468.429993  474.750000  468.299988  474.600006  474.600006
#
#                Volume
# Date
# 2024-01-02  123623700
# 2024-01-03  103585900
# 2024-01-04   84232200
# 2024-01-05   86060800
# 2024-01-08   74879100

# %%
df.tail()
# Out:
#                   Open        High         Low       Close         prc  \
# Date
# 2024-01-25  487.579987  488.309998  485.390015  488.029999  488.029999
# 2024-01-26  487.589996  489.119995  486.540009  487.410004  487.410004
# 2024-01-29  487.730011  491.420013  487.170013  491.269989  491.269989
# 2024-01-30  490.559998  491.619995  490.109985  490.890015  490.890015
# 2024-01-31  488.619995  489.079987  482.859985  482.880005  482.880005
#
#                Volume
# Date
# 2024-01-25   72525000
# 2024-01-26   76641600
# 2024-01-29   61322800
# 2024-01-30   58618400
# 2024-01-31  126011100

# %%
# step 02 generate a new column to get daily returns 'ret'
df['ret'] = df['prc']/df['prc'].shift(1)-1

# %%
df.head()
# Out:
#                   Open        High         Low       Close         prc  \
# Date
# 2024-01-02  472.160004  473.670013  470.489990  472.649994  472.649994
# 2024-01-03  470.429993  471.190002  468.170013  468.790009  468.790009
# 2024-01-04  468.299988  470.959991  467.049988  467.279999  467.279999
# 2024-01-05  467.489990  470.440002  466.429993  467.920013  467.920013
# 2024-01-08  468.429993  474.750000  468.299988  474.600006  474.600006
#
#                Volume       ret
# Date
# 2024-01-02  123623700       NaN
# 2024-01-03  103585900 -0.008167
# 2024-01-04   84232200 -0.003221
# 2024-01-05   86060800  0.001370
# 2024-01-08   74879100  0.014276

# %%
# generate a new column to get daily  log returns 'log_ret'
df['log_ret']=np.log(1+df['ret'])

# %%
df.head()
# Out:
#                   Open        High         Low       Close         prc  \
# Date
# 2024-01-02  472.160004  473.670013  470.489990  472.649994  472.649994
# 2024-01-03  470.429993  471.190002  468.170013  468.790009  468.790009
# 2024-01-04  468.299988  470.959991  467.049988  467.279999  467.279999
# 2024-01-05  467.489990  470.440002  466.429993  467.920013  467.920013
# 2024-01-08  468.429993  474.750000  468.299988  474.600006  474.600006
#
#                Volume       ret   log_ret
# Date
# 2024-01-02  123623700       NaN       NaN
# 2024-01-03  103585900 -0.008167 -0.008200
# 2024-01-04   84232200 -0.003221 -0.003226
# 2024-01-05   86060800  0.001370  0.001369
# 2024-01-08   74879100  0.014276  0.014175

# %%
#summary static of the data
df.describe()
# Out:
#              Open        High         Low       Close         prc  \
# count   21.000000   21.000000   21.000000   21.000000   21.000000
# mean   478.329523  480.378094  476.555240  478.810954  478.810954
# std      7.800500    7.290306    7.611572    7.422096    7.422096
# min    467.489990  470.440002  466.429993  467.279999  467.279999
# 25%    471.869995  474.750000  470.489990  473.880005  473.880005
# 50%    477.589996  478.119995  473.869995  476.559998  476.559998
# 75%    487.579987  488.309998  482.890015  484.859985  484.859985
# max    490.559998  491.619995  490.109985  491.269989  491.269989
#
#              Volume        ret    log_ret
# count  2.100000e+01  20.000000  20.000000
# mean   8.098242e+07   0.001095   0.001071
# std    2.063752e+07   0.007062   0.007062
# min    4.994530e+07  -0.016317  -0.016452
# 25%    6.731060e+07  -0.001943  -0.001945
# 50%    7.664160e+07   0.000893   0.000893
# 75%    8.606080e+07   0.005493   0.005478
# max    1.260111e+08   0.014276   0.014175

# %%
#step 03 create a new column to generate to return cumulative over rolling past 5 days
df['cumulative_ret']= np.exp(df['log_ret'].rolling(5).sum())-1

# %%
df.head()
# Out:
#                   Open        High         Low       Close         prc  \
# Date
# 2024-01-02  472.160004  473.670013  470.489990  472.649994  472.649994
# 2024-01-03  470.429993  471.190002  468.170013  468.790009  468.790009
# 2024-01-04  468.299988  470.959991  467.049988  467.279999  467.279999
# 2024-01-05  467.489990  470.440002  466.429993  467.920013  467.920013
# 2024-01-08  468.429993  474.750000  468.299988  474.600006  474.600006
#
#                Volume       ret   log_ret  cumulative_ret
# Date
# 2024-01-02  123623700       NaN       NaN             NaN
# 2024-01-03  103585900 -0.008167 -0.008200             NaN
# 2024-01-04   84232200 -0.003221 -0.003226             NaN
# 2024-01-05   86060800  0.001370  0.001369             NaN
# 2024-01-08   74879100  0.014276  0.014175             NaN

# %%
# drop missing data rows
df = df.dropna()

# %%
df.head()
# Out:
#                   Open        High         Low       Close         prc  \
# Date
# 2024-01-09  471.869995  474.929993  471.350006  473.880005  473.880005
# 2024-01-10  474.160004  477.450012  473.869995  476.559998  476.559998
# 2024-01-11  477.589996  478.119995  472.260010  476.350006  476.350006
# 2024-01-12  477.839996  478.600006  475.230011  476.679993  476.679993
# 2024-01-16  475.260010  476.609985  473.059998  474.929993  474.929993
#
#               Volume       ret   log_ret  cumulative_ret
# Date
# 2024-01-09  65931400 -0.001517 -0.001518        0.002602
# 2024-01-10  67310600  0.005655  0.005639        0.016575
# 2024-01-11  77940700 -0.000441 -0.000441        0.019410
# 2024-01-12  57944000  0.000693  0.000692        0.018721
# 2024-01-16  85014900 -0.003671 -0.003678        0.000695

# %%
df.describe()
# Out:
#              Open        High         Low       Close         prc  \
# count   16.000000   16.000000   16.000000   16.000000   16.000000
# mean   481.131876  482.933123  479.201254  481.486876  481.486876
# std      6.706971    6.376829    6.725967    6.215555    6.215555
# min    471.820007  472.790009  469.869995  472.290009  472.290009
# 25%    474.985008  477.352509  472.900002  476.454994  476.454994
# 50%    480.925003  483.914993  479.660004  482.654999  482.654999
# 75%    487.625000  488.847488  485.007507  485.895012  485.895012
# max    490.559998  491.619995  490.109985  491.269989  491.269989
#
#              Volume        ret    log_ret  cumulative_ret
# count  1.600000e+01  16.000000  16.000000       16.000000
# mean   7.676557e+07   0.001103   0.001081        0.011756
# std    1.971604e+07   0.006680   0.006689        0.010055
# min    4.994530e+07  -0.016317  -0.016452       -0.005171
# 25%    6.477925e+07  -0.001332  -0.001333        0.002126
# 50%    7.418495e+07   0.000893   0.000893        0.013483
# 75%    8.257748e+07   0.005493   0.005478        0.018893
# max    1.260111e+08   0.012466   0.012389        0.027737

# %%
# create long/short/hold signals
# If cumulative return in 5 days is greater than the 0.01 it should be long signal
# If cumulative return in 5 days is lower than the 0.01 it should be short signal
# Otherwise hold

conditions = [(df['cumulative_ret']>0.01),
              (df['cumulative_ret']<-0.01),
             
    
]

decision = [1,-1]


df['decision'] = np.select(conditions,decision,default= 0)
# Out:
# C:\Users\Lakshan Lahiru\AppData\Local\Temp\ipykernel_4148\532051875.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['decision'] = np.select(conditions,decision,default= 0)

# %%
df
# Out:
#                   Open        High         Low       Close         prc  \
# Date
# 2024-01-09  471.869995  474.929993  471.350006  473.880005  473.880005
# 2024-01-10  474.160004  477.450012  473.869995  476.559998  476.559998
# 2024-01-11  477.589996  478.119995  472.260010  476.350006  476.350006
# 2024-01-12  477.839996  478.600006  475.230011  476.679993  476.679993
# 2024-01-16  475.260010  476.609985  473.059998  474.929993  474.929993
# 2024-01-17  471.820007  472.790009  469.869995  472.290009  472.290009
# 2024-01-18  474.010010  477.059998  472.420013  476.489990  476.489990
# 2024-01-19  477.649994  482.720001  476.540009  482.429993  482.429993
# 2024-01-22  484.010010  485.220001  482.779999  483.450012  483.450012
# 2024-01-23  484.010010  485.109985  482.890015  484.859985  484.859985
# 2024-01-24  487.809998  488.769989  484.880005  485.390015  485.390015
# 2024-01-25  487.579987  488.309998  485.390015  488.029999  488.029999
# 2024-01-26  487.589996  489.119995  486.540009  487.410004  487.410004
# 2024-01-29  487.730011  491.420013  487.170013  491.269989  491.269989
# 2024-01-30  490.559998  491.619995  490.109985  490.890015  490.890015
# 2024-01-31  488.619995  489.079987  482.859985  482.880005  482.880005
#
#                Volume       ret   log_ret  cumulative_ret  decision
# Date
# 2024-01-09   65931400 -0.001517 -0.001518        0.002602         0
# 2024-01-10   67310600  0.005655  0.005639        0.016575         1
# 2024-01-11   77940700 -0.000441 -0.000441        0.019410         1
# 2024-01-12   57944000  0.000693  0.000692        0.018721         1
# 2024-01-16   85014900 -0.003671 -0.003678        0.000695         0
# 2024-01-17   68843900 -0.005559 -0.005574       -0.003355         0
# 2024-01-18   91856200  0.008893  0.008853       -0.000147         0
# 2024-01-19  110733300  0.012466  0.012389        0.012764         1
# 2024-01-22   75844900  0.002114  0.002112        0.014202         1
# 2024-01-23   49945300  0.002916  0.002912        0.020908         1
# 2024-01-24   81765000  0.001093  0.001093        0.027737         1
# 2024-01-25   72525000  0.005439  0.005424        0.024219         1
# 2024-01-26   76641600 -0.001270 -0.001271        0.010323         1
# 2024-01-29   61322800  0.007919  0.007888        0.016175         1
# 2024-01-30   58618400 -0.000773 -0.000774        0.012437         1
# 2024-01-31  126011100 -0.016317 -0.016452       -0.005171         0

# %%
count_long_signals = (df['decision'] == 1).sum()
count_short_signals = (df['decision'] == -1).sum()
hold = (df['decision'] == 0).sum()
print("Number of long signals:", count_long_signals)
print("Number of short signals:", count_short_signals)
print("Number of holds :",hold)
# Out:
# Number of long signals: 11
# Number of short signals: 0
# Number of holds : 5

# %%
#  calculate the cumulative trading profit
df["share"] = df['decision'].shift(1)
df["cum_share"] = df["share"].cumsum()
df["change_price"] = df["prc"].diff(1)
df["Profit"] = df["change_price"]*df["cum_share"]
df["cumu_Profit"] = df["Profit"].cumsum()
df.tail()
# Out:
# C:\Users\Lakshan Lahiru\AppData\Local\Temp\ipykernel_4148\3189698020.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["share"] = df['decision'].shift(1)
# C:\Users\Lakshan Lahiru\AppData\Local\Temp\ipykernel_4148\3189698020.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cum_share"] = df["share"].cumsum()
# C:\Users\Lakshan Lahiru\AppData\Local\Temp\ipykernel_4148\3189698020.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["change_price"] = df["prc"].diff(1)
# C:\Users\Lakshan Lahiru\AppData\Local\Temp\ipykernel_4148\3189698020.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Profit"] = df["change_price"]*df["cum_share"]
# C:\Users\Lakshan Lahiru\AppData\Local\Temp\ipykernel_4148\3189698020.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cumu_Profit"] = df["Profit"].cumsum()
#                   Open        High         Low       Close         prc  \
# Date
# 2024-01-25  487.579987  488.309998  485.390015  488.029999  488.029999
# 2024-01-26  487.589996  489.119995  486.540009  487.410004  487.410004
# 2024-01-29  487.730011  491.420013  487.170013  491.269989  491.269989
# 2024-01-30  490.559998  491.619995  490.109985  490.890015  490.890015
# 2024-01-31  488.619995  489.079987  482.859985  482.880005  482.880005
#
#                Volume       ret   log_ret  cumulative_ret  decision  share  \
# Date
# 2024-01-25   72525000  0.005439  0.005424        0.024219         1    1.0
# 2024-01-26   76641600 -0.001270 -0.001271        0.010323         1    1.0
# 2024-01-29   61322800  0.007919  0.007888        0.016175         1    1.0
# 2024-01-30   58618400 -0.000773 -0.000774        0.012437         1    1.0
# 2024-01-31  126011100 -0.016317 -0.016452       -0.005171         0    1.0
#
#             cum_share  change_price     Profit  cumu_Profit
# Date
# 2024-01-25        7.0      2.639984  18.479889    50.489990
# 2024-01-26        8.0     -0.619995  -4.959961    45.530029
# 2024-01-29        9.0      3.859985  34.739868    80.269897
# 2024-01-30       10.0     -0.379974  -3.799744    76.470154
# 2024-01-31       11.0     -8.010010 -88.110107   -11.639954

# %%
cumu_Profit = df["cumu_Profit"]

# %%
cumu_Profit.iloc[-1]
# Out:
# -11.63995361328125

# %%
# Plot the cumulative graph


import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.title("Total Money you win is " + str(cumu_Profit.iloc[-1]))
df["cumu_Profit"].plot(label='Cumulative Profit',color='green')
plt.legend()

plt.xlabel('Date')
plt.ylabel('Cumulative Profit ')
plt.show()
