# %%
import numpy as np
import pandas as pd

# %%
# Open the download data set and read in pandas dataframe from (2006-01-01 to Now)
df  =pd.read_csv('QQQ (2).csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2006-01-03   40.650002   41.490002   40.160000   41.310001   35.747551
# 1     2006-01-04   41.410000   41.740002   41.320000   41.740002   36.119656
# 2     2006-01-05   41.750000   42.000000   41.709999   41.919998   36.275421
# 3     2006-01-06   42.259998   42.700001   42.060001   42.680000   36.933086
# 4     2006-01-09   42.680000   42.919998   42.520000   42.849998   37.080200
# ...          ...         ...         ...         ...         ...         ...
# 4559  2024-02-14  431.260010  433.649994  428.880005  433.220001  433.220001
# 4560  2024-02-15  433.920013  434.980011  431.329987  434.510010  434.510010
# 4561  2024-02-16  434.890015  434.989990  429.850006  430.570007  430.570007
# 4562  2024-02-20  428.549988  430.079987  423.500000  427.320007  427.320007
# 4563  2024-02-21  424.549988  425.700012  421.630005  425.609985  425.609985
#
#          Volume
# 0     109350400
# ...

# %%
#Step 01 (Rename the column 'Adj Close'  to  'prc' )

# %%
df.rename(columns={'Adj Close':'prc'},inplace=True )

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close        prc  \
# 0  2006-01-03  40.650002  41.490002  40.160000  41.310001  35.747551
# 1  2006-01-04  41.410000  41.740002  41.320000  41.740002  36.119656
# 2  2006-01-05  41.750000  42.000000  41.709999  41.919998  36.275421
# 3  2006-01-06  42.259998  42.700001  42.060001  42.680000  36.933086
# 4  2006-01-09  42.680000  42.919998  42.520000  42.849998  37.080200
#
#       Volume
# 0  109350400
# 1   92769400
# 2   77656900
# 3  110053900
# 4   80768800

# %%
import matplotlib.pyplot as plt
