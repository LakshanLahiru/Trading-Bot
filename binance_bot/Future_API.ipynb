# %%
api_key = "b6ba865a8a866e27a29769183953ae47762ea98861118d3e67c0ea0f52f04488"
secret_key = "af692e426d8f9a27a83c7daeea25a81da4270e22bb8337eb7e858488738babd3"

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com", testnet = True)

# %%
client

# %%
client.futures_account()
# Out:
# {'feeTier': 0,
#  'canTrade': True,
#  'canDeposit': True,
#  'canWithdraw': True,
#  'tradeGroupId': -1,
#  'updateTime': 0,
#  'multiAssetsMargin': False,
#  'totalInitialMargin': '45.92038165',
#  'totalMaintMargin': '1.83681526',
#  'totalWalletBalance': '13789.40247515',
#  'totalUnrealizedProfit': '26.15627112',
#  'totalMarginBalance': '13815.55874627',
#  'totalPositionInitialMargin': '45.92038165',
#  'totalOpenOrderInitialMargin': '0.00000000',
#  'totalCrossWalletBalance': '13741.50140983',
#  'totalCrossUnPnl': '0.00000000',
#  'availableBalance': '13741.50140983',
#  'maxWithdrawAmount': '13741.50140983',
#  'assets': [{'asset': 'BTC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'BNB',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'ETH',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'USDT',
#    'walletBalance': '13789.40247515',
#    'unrealizedProfit': '26.15627112',
#    'marginBalance': '13815.55874627',
#    'maintMargin': '1.83681526',
#    'initialMargin': '45.92038165',
#    'positionInitialMargin': '45.92038165',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '13741.50140983',
#    'crossWalletBalance': '13741.50140983',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '13741.50140983',
#    'marginAvailable': True,
#    'updateTime': 1707128509787},
#   {'asset': 'USDC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'BUSD',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0}],
#  'positions': [{'symbol': 'SNTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SUSHIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'INJUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STRAXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '0',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RDNTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ZRXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HIGHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XAIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WAVESUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SPELLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XTZUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '150000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DARUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'JOEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ETCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '400000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PENDLEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XMRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '150000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ETHUSDT_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '375000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GLMRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '0',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ALICEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HOOKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNBUSDC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ACEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'REEFUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BATUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000BONKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DOGEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '900000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TRXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '90000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STORJUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SNXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XLMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '150000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DOGEUSDC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '1100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IOTXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ARKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '0',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'UMAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DASHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KAVAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OXTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RUNEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'APEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BLUEBIRDUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '600000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KEYUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DGBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SKLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FOOTBALLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ALTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MTLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TOMOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'LTCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ETHBTC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '400',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KSMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TRBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FLOWUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MANAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '150000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CHRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ONDOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GALUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'USDCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '900000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCUSDT_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '375000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RNDRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OGNUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STMXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SRMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BLURUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KNCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ENJUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XRPUSDC',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '750000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ATOMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '600000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'NMRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ENSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GASUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AGIXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ATAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IOSTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HBARUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ZECUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '150000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'POLYXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IDEXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'EDUUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GALAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '900000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GTCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ALGOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MANTAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BSVUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'LRCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PYTHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ORBSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '10000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STGUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ARPAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CELOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'QNTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1INCHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
# ...
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'PERPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RVNUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ARKMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '0',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'NKNUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KLAYUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DEFIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'COMPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCDOMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCUSDT',
#    'initialMargin': '45.92038165',
#    'maintMargin': '1.83681526',
#    'unrealizedProfit': '26.15627112',
#    'positionInitialMargin': '45.92038165',
#    'openOrderInitialMargin': '0',
#    'leverage': '10',
#    'isolated': True,
#    'entryPrice': '43304.75454545',
#    'breakEvenPrice': '45293.40971997',
#    'maxNotional': '40000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.010',
#    'notional': '459.20381658',
#    'isolatedWallet': '47.90106532',
#    'updateTime': 1707436800485,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OMGUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000PEPEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '50000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ICXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000RATSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FETUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SUPERUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'LEVERUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000FLOKIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FTMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '400000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AMBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ETHUSDT_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '375000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SXPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WLDUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XEMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ALTUSDT_240130',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ZILUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DYDXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '400000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AXSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '600000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OCEANUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CHZUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ILVUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DUSKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KASUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ACHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CTSIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'breakEvenPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'}]}

# %%
pd.DataFrame(client.futures_account()["assets"])
# Out:
#   asset   walletBalance unrealizedProfit   marginBalance maintMargin  \
# 0   ETH      0.00000000       0.00000000      0.00000000  0.00000000
# 1   BTC      0.00000000       0.00000000      0.00000000  0.00000000
# 2   BNB      0.00000000       0.00000000      0.00000000  0.00000000
# 3  USDT  13789.40247515      26.15627113  13815.55874628  1.83681527
# 4  USDC      0.00000000       0.00000000      0.00000000  0.00000000
# 5  BUSD      0.00000000       0.00000000      0.00000000  0.00000000
#
#   initialMargin positionInitialMargin openOrderInitialMargin  \
# 0    0.00000000            0.00000000             0.00000000
# 1    0.00000000            0.00000000             0.00000000
# 2    0.00000000            0.00000000             0.00000000
# 3   45.92038166           45.92038166             0.00000000
# 4    0.00000000            0.00000000             0.00000000
# 5    0.00000000            0.00000000             0.00000000
#
#   maxWithdrawAmount crossWalletBalance  crossUnPnl availableBalance  \
# 0        0.00000000         0.00000000  0.00000000       0.00000000
# 1        0.00000000         0.00000000  0.00000000       0.00000000
# 2        0.00000000         0.00000000  0.00000000       0.00000000
# 3    13741.50140983     13741.50140983  0.00000000   13741.50140983
# 4        0.00000000         0.00000000  0.00000000       0.00000000
# 5        0.00000000         0.00000000  0.00000000       0.00000000
#
#    marginAvailable     updateTime
# 0             True              0
# 1             True              0
# 2             True              0
# 3             True  1707128509787
# 4             True              0
# 5             True              0

# %%
client.futures_account_balance()
# Out:
# [{'accountAlias': 'FzSgoCTioCmYXq',
#   'asset': 'BTC',
#   'balance': '0.00000000',
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000',
#   'maxWithdrawAmount': '0.00000000',
#   'marginAvailable': True,
#   'updateTime': 0},
#  {'accountAlias': 'FzSgoCTioCmYXq',
#   'asset': 'BNB',
#   'balance': '0.00000000',
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000',
#   'maxWithdrawAmount': '0.00000000',
#   'marginAvailable': True,
#   'updateTime': 0},
#  {'accountAlias': 'FzSgoCTioCmYXq',
#   'asset': 'ETH',
#   'balance': '0.00000000',
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000',
#   'maxWithdrawAmount': '0.00000000',
#   'marginAvailable': True,
#   'updateTime': 0},
#  {'accountAlias': 'FzSgoCTioCmYXq',
#   'asset': 'USDT',
#   'balance': '13789.40247515',
#   'crossWalletBalance': '13741.50140983',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '13741.50140983',
#   'maxWithdrawAmount': '13741.50140983',
#   'marginAvailable': True,
#   'updateTime': 1707128509787},
#  {'accountAlias': 'FzSgoCTioCmYXq',
#   'asset': 'USDC',
#   'balance': '0.00000000',
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000',
#   'maxWithdrawAmount': '0.00000000',
#   'marginAvailable': True,
#   'updateTime': 0},
#  {'accountAlias': 'FzSgoCTioCmYXq',
#   'asset': 'BUSD',
#   'balance': '0.00000000',
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000',
#   'maxWithdrawAmount': '0.00000000',
#   'marginAvailable': True,
#   'updateTime': 0}]

# %%
client.futures_position_information()
# Out:
# [{'symbol': 'USTCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.02594677',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ONGUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.31622713',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BTCSTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.11612085',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'STEEMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.22030513',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'XRPUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.51947195',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '500000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'CAKEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '2.50081959',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'CHRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.32005936',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ALTUSDT_240130',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.33757438',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ALTUSDT_240426',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.33757438',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'KLAYUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.20829415',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'AGLDUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.26618787',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ACHUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.01840302',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'HIGHUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.42027691',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'RONINUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '2.44137206',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ONDOUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.23070000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'GALAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.02309908',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '900000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ATAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.08720423',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'WOOUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.37257411',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'TWTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.14981794',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'MANAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.45572277',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '150000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'NFPUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.56413396',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BLURUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.63994397',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'CFXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.22660000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '400000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'XRPUSDC',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.51866637',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '750000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ETHBTC',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.05321609',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '400.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ETHWUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '2.72743521',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'API3USDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '3.02160663',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'COMBOUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.70192786',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'LRCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.23484867',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'LINAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00787000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'JTOUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.91028899',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ZENUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '8.31536706',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'HFTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.32698921',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'KSMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '41.18975864',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'UNFIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '5.94000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'MOVRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '22.15593839',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'GLMRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.38342215',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '0.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'SOLUSDC',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '104.41038374',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '2000000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'JUPUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.50270000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'HOTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00194389',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'THETAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.01016036',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '250000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'TRXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.12283398',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '90000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'VETUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.02916883',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '200000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'RSRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00242269',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'LEVERUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00141608',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'AGIXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.29280000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'CYBERUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '7.31372572',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'SXPUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.31792103',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ILVUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '78.84693548',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'LITUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.81625197',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BADGERUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '3.46711347',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ZETAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.21533400',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BAKEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.34420000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'QNTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '104.39722122',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'XAIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.84280693',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ICP2USDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'UMAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '4.20953576',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BIGTIMEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.32850627',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'FETUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.56040000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'SUIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.55732937',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'PENDLEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '2.88814904',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'FLOWUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.80651636',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'XLMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.11065043',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '150000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'IOTAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.24670000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'CTSIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.31043425',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'OGNUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.16012502',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'DODOXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.15629960',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'LQTYUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.34208538',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BTCUSDC',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '45958.36120273',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '80000000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'KNCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.59747288',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': '1000PEPEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00097622',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '50000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'PYTHUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.53103684',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'WIFUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.21608807',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'HBARUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.07582113',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '50000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'RUNEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '4.97579646',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'XTZUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.02255134',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '150000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BONDUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '3.31300000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '10000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ETHUSDT_240628',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '2370.66567033',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '375000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': '1000XECUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.03313171',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ALPHAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.09578583',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'C98USDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.23919466',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'CTKUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.65173595',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ICXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.21962958',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'DASHUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '27.06000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'STXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.85100000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '50000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'DOGEUSDC',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.08043419',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '1100000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'REEFUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00146839',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ALICEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.15600000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'GMTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.24736803',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '150000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'SUSHIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.11711626',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'YFIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '7315.65835576',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'OCEANUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.45606015',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ETCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '25.91774945',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '400000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': '1000SHIBUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00931774',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '300000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'USDCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.00014204',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '900000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BANDUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.90932391',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ORBSUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.03537988',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '10000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'MAGICUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.22744612',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
# ...
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'POLYXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.15992250',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'SKLUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.07396000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'INJUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '33.70100000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '50000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'MKRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1952.34516588',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '450000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'TIAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '19.93078427',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BELUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.59700000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'HIFIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.57112133',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '0.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'NTRNUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.11691191',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ROSEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.11899191',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'SOLUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '104.39500000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '900000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'RNDRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '4.52891431',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'AXSUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '7.28282510',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '600000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'YGGUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.43974268',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '0.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'MDTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.05396777',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'CELRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.01779000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ARPAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.05587714',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'HOOKUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.89724221',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'MEMEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.02296857',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'AMBUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.00826919',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'JOEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.47952976',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ONEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.01468327',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'MTLUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.44605189',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'DEFIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '791.16006486',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BTCDOMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1875.65805898',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'LSKUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '1.36369952',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ETHUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '2445.64523077',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '10',
#   'maxNotionalValue': '30000000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 1672741455560,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'DOGEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.08043547',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '900000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'CHZUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.10132200',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'OPUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '3.32770000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '600000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'BLUEBIRDUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '8.99926501',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '25000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'ADAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.53356817',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '250000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0},
#  {'symbol': 'PHBUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0',
#   'breakEvenPrice': '0',
#   'markPrice': '0.97879499',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0.00000000',
#   'leverage': '20',
#   'maxNotionalValue': '5000.00000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0.00000000',
#   'isolatedWallet': '0.00000000',
#   'updateTime': 0,
#   'isolated': False,
#   'adlQuantile': 0}]

# %%
client.futures_position_information(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.010',
#   'entryPrice': '43304.75454545',
#   'breakEvenPrice': '45293.40971997',
#   'markPrice': '45920.69743805',
#   'unRealizedProfit': '26.15942892',
#   'liquidationPrice': '38669.32531471',
#   'leverage': '10',
#   'maxNotionalValue': '40000000',
#   'marginType': 'isolated',
#   'isolatedMargin': '74.06049424',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '459.20697438',
#   'isolatedWallet': '47.90106532',
#   'updateTime': 1707436800485,
#   'isolated': True,
#   'adlQuantile': 2}]

# %%
client.futures_coin_account()
# Out:
# {'feeTier': 0,
#  'canTrade': True,
#  'canDeposit': True,
#  'canWithdraw': True,
#  'updateTime': 0,
#  'assets': [{'asset': 'AAVE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'APE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'AXS',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'XTZ',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'LTC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'CRV',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'XRP',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'ZIL',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'CHZ',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'DOT',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'THETA',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'GMT',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'KNC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'VET',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'ICX',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'XMR',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'UNI',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'LUNA',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'BCH',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'SOL',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'SAND',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'ETH',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'FTM',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'ETC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'TRX',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'ADA',
#    'walletBalance': '100000.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '100000.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '100000.00000000',
#    'crossWalletBalance': '100000.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '100000.00000000',
#    'updateTime': 1669127998464},
#   {'asset': 'ENS',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'ALGO',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'MATIC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'ATOM',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'OP',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'DOGE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'ROSE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'MANA',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'FIL',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'BTC',
#    'walletBalance': '10.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '10.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '10.00000000',
#    'crossWalletBalance': '10.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '10.00000000',
#    'updateTime': 1669127998448},
#   {'asset': 'APT',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'AVAX',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'GALA',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'EGLD',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'XLM',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'LINK',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'EOS',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'RUNE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'NEAR',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0},
#   {'asset': 'BNB',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'updateTime': 0}],
#  'positions': [{'symbol': 'BCHUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'LTCUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ETCUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'APTUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ADAUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ICXUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'NEARUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'MANAUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '30000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'XRPUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'GMTUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '40000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ADAUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '250000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'LINKUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'LTCUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'AAVEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'SOLUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'XRPUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'THETAUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BCHUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ADAUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'SANDUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'XTZUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BTCUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '30',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'MATICUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '70000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'XLMUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '200000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'LINKUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ATOMUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'EGLDUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'CHZUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '750000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ALGOUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '150000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'OPUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '100000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'XMRUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BCHUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BTCETH_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ETHUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'DOTUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'DOTUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'FTMUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BNBUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '4000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'LUNAUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ROSEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '100000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'KNCUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ENSUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '12000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BTCUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'LINKUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'UNIUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BNBUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '4000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'XRPUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'FILUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'TRXUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'AXSUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '2500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ETHUSD_240628',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'DOGEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BNBUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '4000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'AVAXUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'DOTUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ETCUSD_210924',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'RUNEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '2500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'APEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '2000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'EOSUSD_210924',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'EOSUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '30000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ETHBTC_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'ETHUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'LTCUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'},
#   {'symbol': 'BTCUSD_240329',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '30',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0',
#    'breakEvenPrice': '0.00000000'}]}

# %%
client.futures_coin_account_balance()
# Out:
# [{'accountAlias': 'AusRAufWXqoC',
#   'asset': 'AAVE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'APE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'AXS',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'XTZ',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'LTC',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'CRV',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'XRP',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ZIL',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'CHZ',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'DOT',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'THETA',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'GMT',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'KNC',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'VET',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ICX',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'XMR',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'UNI',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'LUNA',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'BCH',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'SOL',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'SAND',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ETH',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'FTM',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ETC',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'TRX',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ADA',
#   'balance': '100000.00000000',
#   'withdrawAvailable': '100000.00000000',
#   'updateTime': 1669127998464,
#   'crossWalletBalance': '100000.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '100000.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ENS',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ALGO',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'MATIC',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ATOM',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'OP',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'DOGE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'ROSE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'MANA',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'FIL',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'BTC',
#   'balance': '10.00000000',
#   'withdrawAvailable': '10.00000000',
#   'updateTime': 1669127998448,
#   'crossWalletBalance': '10.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '10.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'APT',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'AVAX',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'GALA',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'EGLD',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'XLM',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'LINK',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'EOS',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'RUNE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'NEAR',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'AusRAufWXqoC',
#   'asset': 'BNB',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'}]

# %%
client.futures_coin_position_information()
# Out:
# [{'symbol': 'FILUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'RUNEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '2500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'DOTUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BCHUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ADAUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ETCUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ADAUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'XRPUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BNBUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '4000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BTCUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'LTCUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ETHUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BNBUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '4000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'EGLDUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'XMRUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'XLMUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '200000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ICXUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'LINKUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'XRPUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ALGOUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '150000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ETHBTC_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'THETAUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'UNIUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'LTCUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'MANAUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '30000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ETHUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ETHUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'NEARUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'EOSUSD_210924',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BCHUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'DOTUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'DOTUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'SOLUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'FTMUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'LTCUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'APEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '2000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'XRPUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'APTUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'EOSUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '30000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BTCUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '30',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ADAUSD_240628',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ROSEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'XTZUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'MATICUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '70000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ATOMUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'GMTUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '40000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BTCUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '30',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'SANDUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ETCUSD_210924',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BTCETH_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'KNCUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'LINKUSD_240329',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'CHZUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '750000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'LUNAUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'LINKUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'AVAXUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'OPUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BNBUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '4000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'AXSUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '2500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'BCHUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'TRXUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'DOGEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'AAVEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'},
#  {'symbol': 'ENSUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '12000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0,
#   'breakEvenPrice': '0.00000000'}]

# %%
# placing market order

# %%
client.futures_position_information(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.010',
#   'entryPrice': '43304.75454545',
#   'breakEvenPrice': '45293.40971997',
#   'markPrice': '45920.81771685',
#   'unRealizedProfit': '26.16063171',
#   'liquidationPrice': '38669.32531471',
#   'leverage': '10',
#   'maxNotionalValue': '40000000',
#   'marginType': 'isolated',
#   'isolatedMargin': '74.06169703',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '459.20817716',
#   'isolatedWallet': '47.90106532',
#   'updateTime': 1707436800485,
#   'isolated': True,
#   'adlQuantile': 2}]

# %%
client.futures_change_leverage(symbol = "BTCUSDT", leverage = 50)
# Out:
# {'symbol': 'BTCUSDT', 'leverage': 50, 'maxNotionalValue': '3000000'}

# %%
client.futures_position_information(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.010',
#   'entryPrice': '43304.75454545',
#   'breakEvenPrice': '45293.40971997',
#   'markPrice': '45920.81972592',
#   'unRealizedProfit': '26.16065180',
#   'liquidationPrice': '38669.32531471',
#   'leverage': '50',
#   'maxNotionalValue': '3000000',
#   'marginType': 'isolated',
#   'isolatedMargin': '74.06171712',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '459.20819725',
#   'isolatedWallet': '47.90106532',
#   'updateTime': 1707436800485,
#   'isolated': True,
#   'adlQuantile': 2}]

# %%
client.futures_get_open_orders(symbol = "BTCUSDT")
# Out:
# []

# %%
leverage = 10
size = 0.1

# %%
client.futures_change_leverage(symbol = "BTCUSDT", leverage = leverage)
# Out:
# {'symbol': 'BTCUSDT', 'leverage': 10, 'maxNotionalValue': '40000000'}

# %%
order_open = client.futures_create_order(symbol = "BTCUSDT", side = "BUY",
                                         type = "MARKET", quantity = size)
order_open
# Out:
# {'orderId': 3691399034,
#  'symbol': 'BTCUSDT',
#  'status': 'NEW',
#  'clientOrderId': 'XWZM7SEIA4ISRmPUv9GA4j',
#  'price': '0.00',
#  'avgPrice': '0.00',
#  'origQty': '0.100',
#  'executedQty': '0.000',
#  'cumQty': '0.000',
#  'cumQuote': '0.00000',
#  'timeInForce': 'GTC',
#  'type': 'MARKET',
#  'reduceOnly': False,
#  'closePosition': False,
#  'side': 'BUY',
#  'positionSide': 'BOTH',
#  'stopPrice': '0.00',
#  'workingType': 'CONTRACT_PRICE',
#  'priceProtect': False,
#  'origType': 'MARKET',
#  'priceMatch': 'NONE',
#  'selfTradePreventionMode': 'NONE',
#  'goodTillDate': 0,
#  'updateTime': 1707458685586}

# %%
client.futures_position_information(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.110',
#   'entryPrice': '43304.75454545',
#   'breakEvenPrice': '43322.07644727',
#   'markPrice': '43216.60000000',
#   'unRealizedProfit': '-9.69700000',
#   'liquidationPrice': '39073.90331124',
#   'leverage': '10',
#   'maxNotionalValue': '40000000.00000000',
#   'marginType': 'isolated',
#   'isolatedMargin': '472.88915322',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '4753.82600000',
#   'isolatedWallet': '482.58615322',
#   'updateTime': 1707128467039,
#   'isolated': True,
#   'adlQuantile': 1}]

# %%
order_close = client.futures_create_order(symbol = "BTCUSDT", side = "SELL",
                                          type = "MARKET", quantity = size, reduce_Only = True)
order_close
# Out:
# {'orderId': 3691354776,
#  'symbol': 'BTCUSDT',
#  'status': 'NEW',
#  'clientOrderId': 'YDShglBawFJdeKA0iXT4WU',
#  'price': '0.00',
#  'avgPrice': '0.00',
#  'origQty': '0.100',
#  'executedQty': '0.000',
#  'cumQty': '0.000',
#  'cumQuote': '0.00000',
#  'timeInForce': 'GTC',
#  'type': 'MARKET',
#  'reduceOnly': False,
#  'closePosition': False,
#  'side': 'SELL',
#  'positionSide': 'BOTH',
#  'stopPrice': '0.00',
#  'workingType': 'CONTRACT_PRICE',
#  'priceProtect': False,
#  'origType': 'MARKET',
#  'priceMatch': 'NONE',
#  'selfTradePreventionMode': 'NONE',
#  'goodTillDate': 0,
#  'updateTime': 1707455048686}

# %%
client.futures_get_order(symbol = "BTCUSDT", orderId = order_close["orderId"])
# Out:
# {'orderId': 3687616489,
#  'symbol': 'BTCUSDT',
#  'status': 'FILLED',
#  'clientOrderId': 'O5YF6GW66Rbvajxc3lbGHv',
#  'price': '0.00',
#  'avgPrice': '43142.20000',
#  'origQty': '0.100',
#  'executedQty': '0.100',
#  'cumQuote': '4314.22000',
#  'timeInForce': 'GTC',
#  'type': 'MARKET',
#  'reduceOnly': False,
#  'closePosition': False,
#  'side': 'SELL',
#  'positionSide': 'BOTH',
#  'stopPrice': '0.00',
#  'workingType': 'CONTRACT_PRICE',
#  'priceProtect': False,
#  'origType': 'MARKET',
#  'priceMatch': 'NONE',
#  'selfTradePreventionMode': 'NONE',
#  'goodTillDate': 0,
#  'time': 1707128509779,
#  'updateTime': 1707128509787}

# %%
# Income History

# %%
client.futures_account_trades(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'id': 279388827,
#   'orderId': 3679649717,
#   'side': 'BUY',
#   'price': '42546.10',
#   'qty': '0.010',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '425.46100',
#   'commission': '0.17018440',
#   'commissionAsset': 'USDT',
#   'time': 1706773210567,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389038,
#   'orderId': 3679656746,
#   'side': 'BUY',
#   'price': '42562.90',
#   'qty': '0.003',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '127.68870',
#   'commission': '0.05107548',
#   'commissionAsset': 'USDT',
#   'time': 1706773411161,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389039,
#   'orderId': 3679656746,
#   'side': 'BUY',
#   'price': '42631.80',
#   'qty': '0.097',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '4135.28460',
#   'commission': '1.65411384',
#   'commissionAsset': 'USDT',
#   'time': 1706773411161,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389049,
#   'orderId': 3679657152,
#   'side': 'SELL',
#   'price': '42623.50',
#   'qty': '0.010',
#   'realizedPnl': '0.01370000',
#   'marginAsset': 'USDT',
#   'quoteQty': '426.23500',
#   'commission': '0.17049400',
#   'commissionAsset': 'USDT',
#   'time': 1706773422796,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279389050,
#   'orderId': 3679657152,
#   'side': 'SELL',
#   'price': '42575.20',
#   'qty': '0.097',
#   'realizedPnl': '-4.55220999',
#   'marginAsset': 'USDT',
#   'quoteQty': '4129.79440',
#   'commission': '1.65191776',
#   'commissionAsset': 'USDT',
#   'time': 1706773422796,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279389051,
#   'orderId': 3679657152,
#   'side': 'SELL',
#   'price': '42551.30',
#   'qty': '0.003',
#   'realizedPnl': '-0.21249000',
#   'marginAsset': 'USDT',
#   'quoteQty': '127.65390',
#   'commission': '0.05106156',
#   'commissionAsset': 'USDT',
#   'time': 1706773422796,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279389059,
#   'orderId': 3679657990,
#   'side': 'BUY',
#   'price': '42471',
#   'qty': '0.016',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '679.53600',
#   'commission': '0.27181440',
#   'commissionAsset': 'USDT',
#   'time': 1706773443435,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389060,
#   'orderId': 3679657990,
#   'side': 'BUY',
#   'price': '42471.30',
#   'qty': '0.010',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '424.71300',
#   'commission': '0.16988520',
#   'commissionAsset': 'USDT',
#   'time': 1706773443435,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389061,
#   'orderId': 3679657990,
#   'side': 'BUY',
#   'price': '42479.30',
#   'qty': '0.021',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '892.06530',
#   'commission': '0.35682612',
#   'commissionAsset': 'USDT',
#   'time': 1706773443435,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389062,
#   'orderId': 3679657990,
#   'side': 'BUY',
#   'price': '42487.50',
#   'qty': '0.021',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '892.23750',
#   'commission': '0.35689500',
#   'commissionAsset': 'USDT',
#   'time': 1706773443435,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389063,
#   'orderId': 3679657990,
#   'side': 'BUY',
#   'price': '42495.80',
#   'qty': '0.011',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '467.45380',
#   'commission': '0.18698152',
#   'commissionAsset': 'USDT',
#   'time': 1706773443435,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389064,
#   'orderId': 3679657990,
#   'side': 'BUY',
#   'price': '42504',
#   'qty': '0.021',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '892.58400',
#   'commission': '0.35703360',
#   'commissionAsset': 'USDT',
#   'time': 1706773443435,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389114,
#   'orderId': 3679658991,
#   'side': 'SELL',
#   'price': '42561.10',
#   'qty': '0.100',
#   'realizedPnl': '7.52039999',
#   'marginAsset': 'USDT',
#   'quoteQty': '4256.11000',
#   'commission': '1.70244400',
#   'commissionAsset': 'USDT',
#   'time': 1706773474514,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279389115,
#   'orderId': 3679659008,
#   'side': 'SELL',
#   'price': '42450',
#   'qty': '0.100',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '4245',
#   'commission': '1.69800000',
#   'commissionAsset': 'USDT',
#   'time': 1706773474833,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279389187,
#   'orderId': 3679661185,
#   'side': 'BUY',
#   'price': '42682.40',
#   'qty': '0.050',
#   'realizedPnl': '-11.62000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2134.12000',
#   'commission': '0.85364800',
#   'commissionAsset': 'USDT',
#   'time': 1706773534161,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389188,
#   'orderId': 3679661185,
#   'side': 'BUY',
#   'price': '42700',
#   'qty': '0.050',
#   'realizedPnl': '-12.50000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2135',
#   'commission': '0.85400000',
#   'commissionAsset': 'USDT',
#   'time': 1706773534161,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389265,
#   'orderId': 3679663870,
#   'side': 'BUY',
#   'price': '42700',
#   'qty': '0.100',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '4270',
#   'commission': '1.70800000',
#   'commissionAsset': 'USDT',
#   'time': 1706773606465,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279389717,
#   'orderId': 3679677961,
#   'side': 'SELL',
#   'price': '42503.40',
#   'qty': '0.100',
#   'realizedPnl': '-19.66000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '4250.34000',
#   'commission': '1.70013600',
#   'commissionAsset': 'USDT',
#   'time': 1706774008484,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279389833,
#   'orderId': 3679681864,
#   'side': 'BUY',
#   'price': '42657.90',
#   'qty': '0.010',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '426.57900',
#   'commission': '0.17063160',
#   'commissionAsset': 'USDT',
#   'time': 1706774123365,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279390016,
#   'orderId': 3679687353,
#   'side': 'SELL',
#   'price': '42450',
#   'qty': '0.010',
#   'realizedPnl': '-2.07900000',
#   'marginAsset': 'USDT',
#   'quoteQty': '424.50000',
#   'commission': '0.16980000',
#   'commissionAsset': 'USDT',
#   'time': 1706774286721,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279682823,
#   'orderId': 3687610448,
#   'side': 'BUY',
#   'price': '43310',
#   'qty': '0.010',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '433.10000',
#   'commission': '0.17324000',
#   'commissionAsset': 'USDT',
#   'time': 1707128037407,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279682824,
#   'orderId': 3687610469,
#   'side': 'SELL',
#   'price': '43295.10',
#   'qty': '0.010',
#   'realizedPnl': '-0.14900000',
#   'marginAsset': 'USDT',
#   'quoteQty': '432.95100',
#   'commission': '0.17318040',
#   'commissionAsset': 'USDT',
#   'time': 1707128039226,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279682827,
#   'orderId': 3687610575,
#   'side': 'BUY',
#   'price': '43310',
#   'qty': '0.010',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '433.10000',
#   'commission': '0.17324000',
#   'commissionAsset': 'USDT',
#   'time': 1707128048699,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279682941,
#   'orderId': 3687614780,
#   'side': 'SELL',
#   'price': '43118.50',
#   'qty': '0.010',
#   'realizedPnl': '-1.91500000',
#   'marginAsset': 'USDT',
#   'quoteQty': '431.18500',
#   'commission': '0.17247400',
#   'commissionAsset': 'USDT',
#   'time': 1707128382971,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False},
#  {'symbol': 'BTCUSDT',
#   'id': 279682958,
#   'orderId': 3687615372,
#   'side': 'BUY',
#   'price': '43252.30',
#   'qty': '0.010',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '432.52300',
#   'commission': '0.17300920',
#   'commissionAsset': 'USDT',
#   'time': 1707128428896,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279682964,
#   'orderId': 3687615828,
#   'side': 'BUY',
#   'price': '43310',
#   'qty': '0.100',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '4331',
#   'commission': '1.73240000',
#   'commissionAsset': 'USDT',
#   'time': 1707128467038,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': True},
#  {'symbol': 'BTCUSDT',
#   'id': 279682997,
#   'orderId': 3687616489,
#   'side': 'SELL',
#   'price': '43142.20',
#   'qty': '0.100',
#   'realizedPnl': '-16.25545454',
#   'marginAsset': 'USDT',
#   'quoteQty': '4314.22000',
#   'commission': '1.72568800',
#   'commissionAsset': 'USDT',
#   'time': 1707128509787,
#   'positionSide': 'BOTH',
#   'maker': False,
#   'buyer': False}]

# %%
df = pd.DataFrame(client.futures_account_trades(symbol = "BTCUSDT"))
df
# Out:
#      symbol         id     orderId  side     price    qty   realizedPnl  \
# 0   BTCUSDT  279388827  3679649717   BUY  42546.10  0.010             0
# 1   BTCUSDT  279389038  3679656746   BUY  42562.90  0.003             0
# 2   BTCUSDT  279389039  3679656746   BUY  42631.80  0.097             0
# 3   BTCUSDT  279389049  3679657152  SELL  42623.50  0.010    0.01370000
# 4   BTCUSDT  279389050  3679657152  SELL  42575.20  0.097   -4.55220999
# 5   BTCUSDT  279389051  3679657152  SELL  42551.30  0.003   -0.21249000
# 6   BTCUSDT  279389059  3679657990   BUY     42471  0.016             0
# 7   BTCUSDT  279389060  3679657990   BUY  42471.30  0.010             0
# 8   BTCUSDT  279389061  3679657990   BUY  42479.30  0.021             0
# 9   BTCUSDT  279389062  3679657990   BUY  42487.50  0.021             0
# 10  BTCUSDT  279389063  3679657990   BUY  42495.80  0.011             0
# 11  BTCUSDT  279389064  3679657990   BUY     42504  0.021             0
# 12  BTCUSDT  279389114  3679658991  SELL  42561.10  0.100    7.52039999
# 13  BTCUSDT  279389115  3679659008  SELL     42450  0.100             0
# 14  BTCUSDT  279389187  3679661185   BUY  42682.40  0.050  -11.62000000
# 15  BTCUSDT  279389188  3679661185   BUY     42700  0.050  -12.50000000
# 16  BTCUSDT  279389265  3679663870   BUY     42700  0.100             0
# 17  BTCUSDT  279389717  3679677961  SELL  42503.40  0.100  -19.66000000
# 18  BTCUSDT  279389833  3679681864   BUY  42657.90  0.010             0
# 19  BTCUSDT  279390016  3679687353  SELL     42450  0.010   -2.07900000
# 20  BTCUSDT  279682823  3687610448   BUY     43310  0.010             0
# 21  BTCUSDT  279682824  3687610469  SELL  43295.10  0.010   -0.14900000
# 22  BTCUSDT  279682827  3687610575   BUY     43310  0.010             0
# 23  BTCUSDT  279682941  3687614780  SELL  43118.50  0.010   -1.91500000
# 24  BTCUSDT  279682958  3687615372   BUY  43252.30  0.010             0
# 25  BTCUSDT  279682964  3687615828   BUY     43310  0.100             0
# 26  BTCUSDT  279682997  3687616489  SELL  43142.20  0.100  -16.25545454
#
#    marginAsset    quoteQty  commission commissionAsset           time  \
# 0         USDT   425.46100  0.17018440            USDT  1706773210567
# 1         USDT   127.68870  0.05107548            USDT  1706773411161
# 2         USDT  4135.28460  1.65411384            USDT  1706773411161
# 3         USDT   426.23500  0.17049400            USDT  1706773422796
# 4         USDT  4129.79440  1.65191776            USDT  1706773422796
# 5         USDT   127.65390  0.05106156            USDT  1706773422796
# 6         USDT   679.53600  0.27181440            USDT  1706773443435
# 7         USDT   424.71300  0.16988520            USDT  1706773443435
# 8         USDT   892.06530  0.35682612            USDT  1706773443435
# 9         USDT   892.23750  0.35689500            USDT  1706773443435
# 10        USDT   467.45380  0.18698152            USDT  1706773443435
# 11        USDT   892.58400  0.35703360            USDT  1706773443435
# 12        USDT  4256.11000  1.70244400            USDT  1706773474514
# 13        USDT        4245  1.69800000            USDT  1706773474833
# 14        USDT  2134.12000  0.85364800            USDT  1706773534161
# 15        USDT        2135  0.85400000            USDT  1706773534161
# 16        USDT        4270  1.70800000            USDT  1706773606465
# 17        USDT  4250.34000  1.70013600            USDT  1706774008484
# 18        USDT   426.57900  0.17063160            USDT  1706774123365
# 19        USDT   424.50000  0.16980000            USDT  1706774286721
# 20        USDT   433.10000  0.17324000            USDT  1707128037407
# 21        USDT   432.95100  0.17318040            USDT  1707128039226
# 22        USDT   433.10000  0.17324000            USDT  1707128048699
# 23        USDT   431.18500  0.17247400            USDT  1707128382971
# 24        USDT   432.52300  0.17300920            USDT  1707128428896
# 25        USDT        4331  1.73240000            USDT  1707128467038
# 26        USDT  4314.22000  1.72568800            USDT  1707128509787
#
#    positionSide  maker  buyer
# 0          BOTH  False   True
# 1          BOTH  False   True
# 2          BOTH  False   True
# 3          BOTH  False  False
# 4          BOTH  False  False
# 5          BOTH  False  False
# 6          BOTH  False   True
# 7          BOTH  False   True
# 8          BOTH  False   True
# 9          BOTH  False   True
# 10         BOTH  False   True
# 11         BOTH  False   True
# 12         BOTH  False  False
# 13         BOTH  False  False
# 14         BOTH  False   True
# 15         BOTH  False   True
# 16         BOTH  False   True
# 17         BOTH  False  False
# 18         BOTH  False   True
# 19         BOTH  False  False
# 20         BOTH  False   True
# 21         BOTH  False  False
# 22         BOTH  False   True
# 23         BOTH  False  False
# 24         BOTH  False   True
# 25         BOTH  False   True
# 26         BOTH  False  False

# %%
client.futures_income_history(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.17018440',
#   'asset': 'USDT',
#   'time': 1706773210000,
#   'info': '279388827',
#   'tranId': 90031279388827,
#   'tradeId': '279388827'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.05107548',
#   'asset': 'USDT',
#   'time': 1706773411000,
#   'info': '279389038',
#   'tranId': 90031279389038,
#   'tradeId': '279389038'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-1.65411384',
#   'asset': 'USDT',
#   'time': 1706773411000,
#   'info': '279389039',
#   'tranId': 90031279389039,
#   'tradeId': '279389039'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '0.01370000',
#   'asset': 'USDT',
#   'time': 1706773422000,
#   'info': '279389049',
#   'tranId': 90030279389049,
#   'tradeId': '279389049'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.17049400',
#   'asset': 'USDT',
#   'time': 1706773422000,
#   'info': '279389049',
#   'tranId': 90030279389049,
#   'tradeId': '279389049'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-4.55220999',
#   'asset': 'USDT',
#   'time': 1706773422000,
#   'info': '279389050',
#   'tranId': 90030279389050,
#   'tradeId': '279389050'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-1.65191776',
#   'asset': 'USDT',
#   'time': 1706773422000,
#   'info': '279389050',
#   'tranId': 90030279389050,
#   'tradeId': '279389050'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-0.21249000',
#   'asset': 'USDT',
#   'time': 1706773422000,
#   'info': '279389051',
#   'tranId': 90030279389051,
#   'tradeId': '279389051'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.05106156',
#   'asset': 'USDT',
#   'time': 1706773422000,
#   'info': '279389051',
#   'tranId': 90030279389051,
#   'tradeId': '279389051'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.27181440',
#   'asset': 'USDT',
#   'time': 1706773443000,
#   'info': '279389059',
#   'tranId': 90031279389059,
#   'tradeId': '279389059'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.16988520',
#   'asset': 'USDT',
#   'time': 1706773443000,
#   'info': '279389060',
#   'tranId': 90031279389060,
#   'tradeId': '279389060'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.35682612',
#   'asset': 'USDT',
#   'time': 1706773443000,
#   'info': '279389061',
#   'tranId': 90031279389061,
#   'tradeId': '279389061'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.35689500',
#   'asset': 'USDT',
#   'time': 1706773443000,
#   'info': '279389062',
#   'tranId': 90031279389062,
#   'tradeId': '279389062'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.18698152',
#   'asset': 'USDT',
#   'time': 1706773443000,
#   'info': '279389063',
#   'tranId': 90031279389063,
#   'tradeId': '279389063'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.35703360',
#   'asset': 'USDT',
#   'time': 1706773443000,
#   'info': '279389064',
#   'tranId': 90031279389064,
#   'tradeId': '279389064'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '7.52039999',
#   'asset': 'USDT',
#   'time': 1706773474000,
#   'info': '279389114',
#   'tranId': 90030279389114,
#   'tradeId': '279389114'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-1.70244400',
#   'asset': 'USDT',
#   'time': 1706773474000,
#   'info': '279389114',
#   'tranId': 90030279389114,
#   'tradeId': '279389114'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-1.69800000',
#   'asset': 'USDT',
#   'time': 1706773474000,
#   'info': '279389115',
#   'tranId': 90030279389115,
#   'tradeId': '279389115'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-11.62000000',
#   'asset': 'USDT',
#   'time': 1706773534000,
#   'info': '279389187',
#   'tranId': 90031279389187,
#   'tradeId': '279389187'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.85364800',
#   'asset': 'USDT',
#   'time': 1706773534000,
#   'info': '279389187',
#   'tranId': 90031279389187,
#   'tradeId': '279389187'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-12.50000000',
#   'asset': 'USDT',
#   'time': 1706773534000,
#   'info': '279389188',
#   'tranId': 90031279389188,
#   'tradeId': '279389188'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.85400000',
#   'asset': 'USDT',
#   'time': 1706773534000,
#   'info': '279389188',
#   'tranId': 90031279389188,
#   'tradeId': '279389188'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-1.70800000',
#   'asset': 'USDT',
#   'time': 1706773606000,
#   'info': '279389265',
#   'tranId': 90031279389265,
#   'tradeId': '279389265'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-19.66000000',
#   'asset': 'USDT',
#   'time': 1706774008000,
#   'info': '279389717',
#   'tranId': 90030279389717,
#   'tradeId': '279389717'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-1.70013600',
#   'asset': 'USDT',
#   'time': 1706774008000,
#   'info': '279389717',
#   'tranId': 90030279389717,
#   'tradeId': '279389717'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.17063160',
#   'asset': 'USDT',
#   'time': 1706774123000,
#   'info': '279389833',
#   'tranId': 90031279389833,
#   'tradeId': '279389833'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-2.07900000',
#   'asset': 'USDT',
#   'time': 1706774286000,
#   'info': '279390016',
#   'tranId': 90030279390016,
#   'tradeId': '279390016'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.16980000',
#   'asset': 'USDT',
#   'time': 1706774286000,
#   'info': '279390016',
#   'tranId': 90030279390016,
#   'tradeId': '279390016'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.17324000',
#   'asset': 'USDT',
#   'time': 1707128037000,
#   'info': '279682823',
#   'tranId': 90031279682823,
#   'tradeId': '279682823'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-0.14900000',
#   'asset': 'USDT',
#   'time': 1707128039000,
#   'info': '279682824',
#   'tranId': 90030279682824,
#   'tradeId': '279682824'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.17318040',
#   'asset': 'USDT',
#   'time': 1707128039000,
#   'info': '279682824',
#   'tranId': 90030279682824,
#   'tradeId': '279682824'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.17324000',
#   'asset': 'USDT',
#   'time': 1707128048000,
#   'info': '279682827',
#   'tranId': 90031279682827,
#   'tradeId': '279682827'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-1.91500000',
#   'asset': 'USDT',
#   'time': 1707128382000,
#   'info': '279682941',
#   'tranId': 90030279682941,
#   'tradeId': '279682941'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.17247400',
#   'asset': 'USDT',
#   'time': 1707128382000,
#   'info': '279682941',
#   'tranId': 90030279682941,
#   'tradeId': '279682941'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.17300920',
#   'asset': 'USDT',
#   'time': 1707128428000,
#   'info': '279682958',
#   'tranId': 90031279682958,
#   'tradeId': '279682958'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-1.73240000',
#   'asset': 'USDT',
#   'time': 1707128467000,
#   'info': '279682964',
#   'tranId': 90031279682964,
#   'tradeId': '279682964'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-16.25545454',
#   'asset': 'USDT',
#   'time': 1707128509000,
#   'info': '279682997',
#   'tranId': 90030279682997,
#   'tradeId': '279682997'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-1.72568800',
#   'asset': 'USDT',
#   'time': 1707128509000,
#   'info': '279682997',
#   'tranId': 90030279682997,
#   'tradeId': '279682997'}]

# %%
pd.DataFrame(client.futures_income_history(symbol = "BTCUSDT")).tail(6)
# Out:
#      symbol    incomeType        income asset           time       info  \
# 32  BTCUSDT  REALIZED_PNL   -1.91500000  USDT  1707128382000  279682941
# 33  BTCUSDT    COMMISSION   -0.17247400  USDT  1707128382000  279682941
# 34  BTCUSDT    COMMISSION   -0.17300920  USDT  1707128428000  279682958
# 35  BTCUSDT    COMMISSION   -1.73240000  USDT  1707128467000  279682964
# 36  BTCUSDT  REALIZED_PNL  -16.25545454  USDT  1707128509000  279682997
# 37  BTCUSDT    COMMISSION   -1.72568800  USDT  1707128509000  279682997
#
#             tranId    tradeId
# 32  90030279682941  279682941
# 33  90030279682941  279682941
# 34  90031279682958  279682958
# 35  90031279682964  279682964
# 36  90030279682997  279682997
# 37  90030279682997  279682997

# %%
from binance.client import Client
from binance import ThreadedWebsocketManager
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time

# %%
class FuturesTrader():  # Triple SMA Crossover
    
    def __init__(self, symbol, bar_length, sma_s, sma_m, sma_l, units, position = 0, leverage = 5):
        
        self.symbol = symbol
        self.bar_length = bar_length
        self.available_intervals = ["1m", "3m", "5m", "15m", "30m", "1h", "2h", "4h", "6h", "8h", "12h", "1d", "3d", "1w", "1M"]
        self.units = units
        self.position = position
        self.leverage = leverage # NEW
        self.cum_profits = 0 # NEW
        #self.trades = 0 
        #self.trade_values = []
        
        #*****************add strategy-specific attributes here******************
        self.SMA_S = sma_s
        self.SMA_M = sma_m
        self.SMA_L = sma_l
        #************************************************************************
    
    def start_trading(self, historical_days):
        
        client.futures_change_leverage(symbol = self.symbol, leverage = self.leverage) # NEW
        
        self.twm = ThreadedWebsocketManager(testnet = True) # testnet
        self.twm.start()
        
        if self.bar_length in self.available_intervals:
            self.get_most_recent(symbol = self.symbol, interval = self.bar_length,
                                 days = historical_days)
            self.twm.start_kline_futures_socket(callback = self.stream_candles,
                                        symbol = self.symbol, interval = self.bar_length) # Adj: start_kline_futures_socket
            
        # "else" to be added later in the course 
    
    def get_most_recent(self, symbol, interval, days):
    
        now = datetime.utcnow()
        past = str(now - timedelta(days = days))
    
        bars = client.futures_historical_klines(symbol = symbol, interval = interval,
                                            start_str = past, end_str = None, limit = 1000) # Adj: futures_historical_klines
        df = pd.DataFrame(bars)
        df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")
        df.columns = ["Open Time", "Open", "High", "Low", "Close", "Volume",
                      "Clos Time", "Quote Asset Volume", "Number of Trades",
                      "Taker Buy Base Asset Volume", "Taker Buy Quote Asset Volume", "Ignore", "Date"]
        df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()
        df.set_index("Date", inplace = True)
        for column in df.columns:
            df[column] = pd.to_numeric(df[column], errors = "coerce")
        df["Complete"] = [True for row in range(len(df)-1)] + [False]
        
        self.data = df
    
    def stream_candles(self, msg):
        
        # extract the required items from msg
        event_time = pd.to_datetime(msg["E"], unit = "ms")
        start_time = pd.to_datetime(msg["k"]["t"], unit = "ms")
        first   = float(msg["k"]["o"])
        high    = float(msg["k"]["h"])
        low     = float(msg["k"]["l"])
        close   = float(msg["k"]["c"])
        volume  = float(msg["k"]["v"])
        complete=       msg["k"]["x"]
        
        # print out
        print(".", end = "", flush = True) 
    
        # feed df (add new bar / update latest bar)
        self.data.loc[start_time] = [first, high, low, close, volume, complete]
        
        # prepare features and define strategy/trading positions whenever the latest bar is complete
        if complete == True:
            self.define_strategy()
            self.execute_trades()
        
    def define_strategy(self):
        
        data = self.data.copy()
        
        #******************** define your strategy here ************************
        data = data[["Close"]].copy()
        
        data["SMA_S"] = data.Close.rolling(window = self.SMA_S).mean()
        data["SMA_M"] = data.Close.rolling(window = self.SMA_M).mean()
        data["SMA_L"] = data.Close.rolling(window = self.SMA_L).mean()
        
        data.dropna(inplace = True)
                
        cond1 = (data.SMA_S > data.SMA_M) & (data.SMA_M > data.SMA_L)
        cond2 = (data.SMA_S < data.SMA_M) & (data.SMA_M < data.SMA_L)
        
        data["position"] = 0
        data.loc[cond1, "position"] = 1
        data.loc[cond2, "position"] = -1
        #***********************************************************************
        
        self.prepared_data = data.copy()
    
    def execute_trades(self): # Adj! 
        if self.prepared_data["position"].iloc[-1] == 1: # if position is long -> go/stay long
            if self.position == 0:
                order = client.futures_create_order(symbol = self.symbol, side = "BUY", type = "MARKET", quantity = self.units)
                self.report_trade(order, "GOING LONG")  
            elif self.position == -1:
                order = client.futures_create_order(symbol = self.symbol, side = "BUY", type = "MARKET", quantity = 2 * self.units)
                self.report_trade(order, "GOING LONG")
            self.position = 1
        elif self.prepared_data["position"].iloc[-1] == 0: # if position is neutral -> go/stay neutral
            if self.position == 1:
                order = client.futures_create_order(symbol = self.symbol, side = "SELL", type = "MARKET", quantity = self.units)
                self.report_trade(order, "GOING NEUTRAL") 
            elif self.position == -1:
                order = client.futures_create_order(symbol = self.symbol, side = "BUY", type = "MARKET", quantity = self.units)
                self.report_trade(order, "GOING NEUTRAL")
            self.position = 0
        if self.prepared_data["position"].iloc[-1] == -1: # if position is short -> go/stay short
            if self.position == 0:
                order = client.futures_create_order(symbol = self.symbol, side = "SELL", type = "MARKET", quantity = self.units)
                self.report_trade(order, "GOING SHORT") 
            elif self.position == 1:
                order = client.futures_create_order(symbol = self.symbol, side = "SELL", type = "MARKET", quantity = 2 * self.units)
                self.report_trade(order, "GOING SHORT")
            self.position = -1
    
    def report_trade(self, order, going): # Adj!
        
        time.sleep(0.1)
        order_time = order["updateTime"]
        trades = client.futures_account_trades(symbol = self.symbol, startTime = order_time)
        order_time = pd.to_datetime(order_time, unit = "ms")
        
        # extract data from trades object
        df = pd.DataFrame(trades)
        columns = ["qty", "quoteQty", "commission","realizedPnl"]
        for column in columns:
            df[column] = pd.to_numeric(df[column], errors = "coerce")
        base_units = round(df.qty.sum(), 5)
        quote_units = round(df.quoteQty.sum(), 5)
        commission = -round(df.commission.sum(), 5)
        real_profit = round(df.realizedPnl.sum(), 5)
        price = round(quote_units / base_units, 5)
        
        # calculate cumulative trading profits
        self.cum_profits += round((commission + real_profit), 5)
        
        # print trade report
        print(2 * "\n" + 100* "-")
        print("{} | {}".format(order_time, going)) 
        print("{} | Base_Units = {} | Quote_Units = {} | Price = {} ".format(order_time, base_units, quote_units, price))
        print("{} | Profit = {} | CumProfits = {} ".format(order_time, real_profit, self.cum_profits))
        print(100 * "-" + "\n")

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com", testnet = True)

# %%
symbol = "BTCUSDT"
bar_length = "1m"
sma_s = 10
sma_m = 20
sma_l = 50
units = 0.001
position = 0
leverage = 10

# %%
trader = FuturesTrader(symbol = symbol, bar_length = bar_length,
                       sma_s = sma_s, sma_m = sma_m, sma_l = sma_l, 
                       units = units, position = position, leverage = leverage)

# %%
trader.start_trading(historical_days = 1/24)
# Out:
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "C:\Users\Lakshan Lahiru\anaconda3\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Lakshan Lahiru\anaconda3\Lib\site-packages\binance\threaded_stream.py", line 59, in run
#     self._loop.run_until_complete(self.socket_listener())
#   File "C:\Users\Lakshan Lahiru\anaconda3\Lib\asyncio\base_events.py", line 629, in run_until_complete
#     self._check_running()
#   File "C:\Users\Lakshan Lahiru\anaconda3\Lib\asyncio\base_events.py", line 588, in _check_running
#     raise RuntimeError('This event loop is already running')
# RuntimeError: This event loop is already running
# C:\Users\Lakshan Lahiru\anaconda3\Lib\threading.py:1040: RuntimeWarning: coroutine 'ThreadedApiManager.socket_listener' was never awaited
#   self._invoke_excepthook(self)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
while True:
    time.sleep(120)
    twm.stop()
    break
